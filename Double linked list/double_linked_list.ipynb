# %%
#Node ou nó
class Node:
  def __init__(self, label):
    self.prev = None
    self.label = label
    self.next = None
    self.body_removed = False

  def getPrev(self):
    return self.prev

  def setPrev(self, prev):
    self.prev = prev

  def getLabel(self):
    return self.label

  def setLabel(self, label):
    self.label = label

  def getNext(self):
    return self.next

  def setNext(self, next):
    self.next = next

class DoubleLinkedList:

  def __init__(self, size):
    self.first = None
    self.len_list = 0
    self.size = size

# Para o "ADD"
  def push(self, label): #inserir ordenado    
    node = Node(label) #cria o novo nó

    # Lista vazia, simplesmente faz a LinkedList apontar para o novo node
    if self.empty():
      self.first = node

    # Lista não vazia
    else:
      if label < self.first.getLabel():
        #inserção no começo
        node.setNext(self.first) # node apontar  para  o começo da lista
        self.first.setPrev(node) # Mudança devido a LISTA DUPLAMENTE ENCADEADA
        self.first = node # LinkedList apontar para o novo node 

      else:
        # Inserir no meio ou no final
        aux1 = self.first
        aux2 = self.first.getNext()
        flag_insert = False
        while aux2 != None:
          if label < aux2.getLabel():
            # Inserir no meio
            node.setPrev(aux1) # Mudança devido a LISTA DUPLAMENTE ENCADEADA
            node.setNext(aux1.getNext()) #node.setNext(aux2) 
            aux1.setNext(node)
            aux2.setPrev(node) # Mudança devido a LISTA DUPLAMENTE ENCADEADA
            flag_insert = True
            break
          aux1 = aux1.getNext()
          aux2 = aux2.getNext()
        #inserir no final
        if flag_insert == False:
          aux1.setNext(node) 
          node.setPrev(aux1) # Mudança devido a LISTA DUPLAMENTE ENCADEADA      
    self.len_list += 1
       
  def pop(self, label):
    # Não remover de uma lista vazia  
    if not self.empty():
      flag_remove = False

      # Remover de uma lista com apenas 1 elemento
      if self.first.getNext() == None and self.first.getLabel() == label:
        self.first = None
        flag_remove = True

      # Remover o primeiro node da lista
      elif self.first.getLabel() == label:
        self.first = self.first.getNext()
        self.first.setPrev(None) # Mudança devido a LISTA DUPLAMENTE ENCADEADA
        flag_remove = True

      # Remover do meio ou final da lista
      else:
        aux1 = self.first
        aux2 = self.first.getNext()
        while aux2 != None:
          if aux2.getLabel() == label:
            aux1.setNext(aux2.getNext())
            if aux2.getNext() != None:
              aux2 = aux2.getNext() # Mudança devido a LISTA DUPLAMENTE ENCADEADA
              aux2.setPrev(aux1) # ou em 1 linha aux2.getNext().setPrev(aux1) # Mudança devido a LISTA DUPLAMENTE ENCADEADA
            flag_remove = True
            break
          aux1 = aux1.getNext()
          aux2 = aux2.getNext()

      if flag_remove == True:
        self.len_list -= 1
      else:
        print("Label não encontrada")

# Para o "REM"
  def remove_body(self, label):
    flag = False # Flag vai me retornar True = Se for para eu printar o valor da outra var
                 # Ou vai me retornar False = para eu retornar um ?.?

    if not self.empty():
      # Remover de uma lista com apenas 1 elemento
      if self.first.getNext() == None or self.first.getLabel() == label:
        self.first.body_removed = True
        return True, '0'        

      # Remover do meio ou final da lista
      else:
        aux1 = self.first # Node
        cont = 0
        while aux1 != None:
          if aux1.getLabel() == label:
            aux1.body_removed = True
            flag = True
            return flag, str(cont)
          aux1 = aux1.getNext()
          cont = cont + 1

        if flag == False:
          return flag, str(cont)
    
    else:
      print("Lista vazia - Função remove_body")

# Para o "QRY"
  def locate_num(self, label):
    flag = False # Flag vai me retornar True = Se for para eu printar o valor da outra var
                 # Ou vai me retornar False = para eu retornar um ?.?
                 
    if not self.empty():
      # Remover de uma lista com apenas 1 elemento
      # MUDEEEEEEEEEEEEIIIIIIIIII AQUUUUUUUUUUUUI, ANTES ERA OR
      if self.first.getNext() == None or self.first.getLabel() == label:
        flag = True
        return flag, '0'

      # Remover do meio ou final da lista
      else:
        aux1 = self.first # Node
        cont = 0
        while aux1 != None:
          if aux1.getLabel() == label:
            flag = True
            return flag, str(cont)
          aux1 = aux1.getNext()
          cont = cont + 1

        # TODO: Preciso achar uma forma de printar isso, se eu não achar nada vou precisar printar isso, mas o código coloca um print(f"{andar}." + locate_num(label)")
        if flag == False:
          return flag, str(cont)

    else:
        print("Lista vazia da função 'locate_num(self, label)'")

  def empty (self):
    if self.len_list == 0:
    # if self.first == None
      return True
    return False

  def length(self):
    return self.len_list

  def show(self):
    if not self.empty():
      aux = self.first

      print("Ordem crescente: ")
      while aux.getNext() != None:
        print(aux.getLabel(), end=' -> ')
        aux = aux.getNext()
      print(aux.getLabel(), end=' ')
      print('')

      print('\n')

      # Percorrendo na ordem inversa
      # print("Ordem decrescente: ")
      # while aux.getPrev() != None:
      #   print(aux.getLabel(), end=' -> ')
      #   aux = aux.getPrev()      
      # print(aux.getLabel(), end=' ')  
      # print('')

  def clear(self):
        self.first = None
        self.len_list = 0

# %% [markdown]
# ##### A estrutura de jazigos
#
# Em cada andar teremos uma distribuição dessa.
#
# Então por exemplo:
#
# input[0] = M L
#
# M -> Número inicial de andares, será o meu andares.len() = M </br>
# L -> Número de jazigos por andar do cemitério
#
# Logo depois virá uma sequência de instruções "ADD", "REM" e "QRY" seguido por "K" (o número do seguro social).</br>
#
# * Para determinar o andar que acessaremos para alocar o corpo faremos um M % K == M mod K -> Isso resultará no número</br>
# do andar que deveremos acessar para alocar o corpo no jazido daquele andar.</br>
#
# * Cada andar terá a estrutura de double linked list, com um lenght máximo de L.</br>
#
# * Se não ouver mais espaços disponíveis no andar que aquele corpo deveria entrar faremos o insert do corpo no próximo andar,</br>
# obedencendo sempre a mesma regra, em ordem crescente, se não tiver mais espaço avançar para o próximo andar.</br>
#
# * SE NÃO HOUVER MAIS JAZIDOS DISPONÍVEIS NAQUELE CEMITÉRIO, A LEI LOCAL MANDA QUE UM NOVO PRÉDIO DE 2M + 1 ANDARES,</br>
# COM OS MESMOS L TÚMULOS POR ANDAR, SEJA IMEDIATAMENTE CONSTRUIDO NO LOCAL. OS TUMULOS VAZIOS SÃO IGNORADOS, OU SEJA,</br>
# NÃO IREMOS TRATA-LOS.

# %%
cemiterio = DoubleLinkedList(1)

cemiterio.push(5)
cemiterio.push(25)
cemiterio.push(76)
cemiterio.push(32)

cemiterio.pop(5)

cemiterio.show()
cemiterio.clear()

cemiterio.length()
# Out:
# Ordem crescente:
# 25 -> 32 -> 76
# 0

# %%
#entrada0 = input("Valores para M L = ").split(' ')

M = 1 # int(entrada0[0])
L = 11 # int(entrada0[-1])

print("Andares          (M) = " + str(M) + '\n' + "Jazidas - Covas  (L) = " + str(L) ) # Número de ANDARES
# Out:
# Andares          (M) = 1
# Jazidas - Covas  (L) = 11

# %%
predio = {}

for i in range(M):
    # Dicionário que receberá uma double linked list.
    # L = self.size = size ; size é um parâmetro que usaremos para comparar e descobrir se todas as Jazidas estão ocupadas.
    predio[f'Andar {i}'] = DoubleLinkedList(L)

# %%
entrada_ = """ADD 74894
ADD 92325
ADD 47205
ADD 20184
ADD 75837
ADD 90523
ADD 91697
ADD 33302
ADD 79362
ADD 41288
ADD 49739
ADD 38145
ADD 74919
ADD 94022
ADD 2564
ADD 39908
ADD 79448
ADD 18241
ADD 79704
ADD 59722
ADD 66853
ADD 77084
ADD 64023
ADD 51796
ADD 43439
ADD 91429
END
"""

entrada_ = entrada_.split('\n')
print(entrada_)
print(len(entrada_))

# %%
# # #entrada 2 - Poucos elementos
# entrada_ = """ADD 74894
# ADD 92325
# ADD 47205
# ADD 20184
# ADD 75837
# ADD 90523
# ADD 91697
# ADD 33302
# ADD 79362
# ADD 41288
# ADD 49739
# ADD 38145
# ADD 74919
# ADD 94022
# ADD 2564
# ADD 39908
# ADD 79448
# ADD 18241
# ADD 79704
# ADD 59722
# ADD 66853
# ADD 77084
# ADD 64023
# ADD 51796
# ADD 43439
# ADD 91429
# ADD 18178
# ADD 148
# ADD 29968
# ADD 76064
# ADD 39497
# ADD 41388
# QRY 99999
# ADD 49673
# QRY 66853
# ADD 62842
# ADD 25931
# ADD 85426
# QRY 94022
# ADD 14379
# ADD 4711
# ADD 96017
# QRY 99999
# ADD 97506
# ADD 57742
# QRY 99999
# ADD 28786
# ADD 65726
# QRY 97506
# QRY 91697
# ADD 27604
# QRY 92325
# ADD 85918
# ADD 94020
# QRY 96017
# ADD 94788
# QRY 47205
# ADD 31063
# ADD 81892
# QRY 79448
# QRY 85918
# QRY 27604
# ADD 63027
# QRY 99999
# ADD 98728
# QRY 31063
# QRY 65726
# ADD 81132
# QRY 99999
# QRY 74894
# QRY 66853
# QRY 99999
# ADD 68104
# QRY 99999
# QRY 66853
# QRY 74919
# ADD 24470
# QRY 99999
# QRY 79362
# ADD 60268
# QRY 94020
# QRY 99999
# ADD 51172
# QRY 99999
# ADD 54502
# QRY 24470
# QRY 99999
# ADD 17259
# ADD 90456
# ADD 43853
# ADD 34381
# ADD 98498
# ADD 20293
# QRY 47205
# QRY 27604
# QRY 98498
# QRY 18241
# ADD 66718
# QRY 92325
# ADD 97293
# ADD 28975
# QRY 99999
# QRY 20293
# ADD 51579
# QRY 28975
# ADD 98229
# QRY 99999
# ADD 75363
# ADD 46956
# QRY 98498
# ADD 68171
# QRY 99999
# QRY 99999
# QRY 24470
# ADD 46298
# QRY 99999
# ADD 89192
# ADD 1216
# ADD 26657
# QRY 43853
# QRY 28786
# ADD 11926
# ADD 35077
# ADD 37078
# ADD 87851
# QRY 87851
# QRY 99999
# QRY 79448
# QRY 20293
# QRY 18241
# ADD 98948
# QRY 49673
# ADD 77196
# ADD 26361
# ADD 43850
# ADD 65816
# ADD 64013
# QRY 28975
# QRY 28975
# ADD 42539
# QRY 99999
# ADD 70431
# ADD 15848
# ADD 48620
# QRY 99999
# QRY 99999
# ADD 50026
# QRY 31063
# QRY 98948
# ADD 67633
# QRY 28975
# ADD 67087
# QRY 99999
# QRY 99999
# QRY 99999
# QRY 64013
# ADD 93231
# QRY 99999
# QRY 97506
# QRY 64013
# ADD 50887
# ADD 20106
# ADD 45459
# QRY 99999
# ADD 55515
# QRY 46298
# ADD 35311
# QRY 15848
# ADD 526
# QRY 64023
# ADD 71649
# ADD 48347
# QRY 57742
# ADD 57472
# QRY 89192
# QRY 67087
# ADD 99167
# QRY 42539
# ADD 98973
# QRY 43439
# ADD 88273
# QRY 93231
# ADD 29735
# QRY 99999
# ADD 53704
# ADD 13550
# ADD 27677
# ADD 90839
# ADD 63003
# QRY 91697
# QRY 47205
# ADD 93227
# ADD 40364
# ADD 40758
# QRY 49739
# QRY 55515
# QRY 51579
# ADD 9663
# ADD 21094
# ADD 69148
# QRY 74919
# QRY 98728
# ADD 50971
# QRY 64013
# QRY 39497
# ADD 65037
# ADD 52997
# ADD 22471
# QRY 68104
# QRY 50971
# ADD 14787
# ADD 51340
# ADD 48489
# QRY 57742
# QRY 39908
# QRY 99999
# ADD 38673
# ADD 65030
# QRY 99999
# ADD 14747
# QRY 91697
# QRY 99999
# QRY 26361
# ADD 30364
# ADD 14708
# ADD 42422
# ADD 68633
# ADD 5498
# QRY 75363
# ADD 22722
# ADD 50895
# ADD 95095
# ADD 51615
# ADD 98437
# QRY 43853
# ADD 77375
# QRY 99999
# QRY 87851
# QRY 68104
# ADD 53496
# QRY 99999
# QRY 31063
# QRY 88273
# QRY 17259
# QRY 99999
# ADD 30517
# QRY 99999
# QRY 43850
# ADD 46964
# ADD 54262
# QRY 93231
# QRY 57742
# ADD 42965
# ADD 20963
# QRY 99999
# ADD 65851
# ADD 28905
# ADD 61616
# QRY 98437
# QRY 51615
# QRY 28786
# QRY 85426
# ADD 31768
# ADD 27581
# QRY 148
# QRY 40364
# QRY 14379
# QRY 48489
# QRY 4711
# ADD 7477
# ADD 78096
# QRY 34381
# QRY 60268
# QRY 42965
# ADD 61214
# ADD 25479
# ADD 4278
# ADD 88788
# QRY 99999
# ADD 90946
# QRY 99999
# ADD 33816
# QRY 17259
# ADD 21532
# QRY 90456
# ADD 7890
# ADD 31207
# ADD 27498
# ADD 54019
# ADD 45435
# ADD 8739
# QRY 76064
# QRY 39908
# QRY 88788
# QRY 60268
# ADD 68749
# QRY 89192
# QRY 77196
# QRY 99999
# QRY 7477
# ADD 103
# QRY 67633
# ADD 87919
# QRY 99999
# QRY 99999
# ADD 17929
# ADD 71918
# ADD 98148
# ADD 19417
# ADD 75000
# ADD 15215
# QRY 65037
# ADD 69828
# QRY 47205
# QRY 7890
# ADD 65985
# QRY 99999
# ADD 62443
# QRY 22471
# ADD 92600
# ADD 20526
# QRY 99999
# ADD 98866
# QRY 52997
# QRY 99999
# ADD 89453
# ADD 8341
# QRY 51579
# ADD 18104
# ADD 80805
# QRY 99999
# QRY 99999
# ADD 53285
# QRY 51615
# ADD 5103
# QRY 99999
# ADD 258
# QRY 103
# QRY 99999
# QRY 99999
# QRY 99999
# QRY 20184
# QRY 28905
# QRY 93231
# QRY 93231
# ADD 46604
# ADD 57153
# QRY 57153
# ADD 67574
# QRY 57472
# QRY 70431
# ADD 77650
# QRY 98866
# QRY 53285
# QRY 77084
# QRY 13550
# QRY 20293
# ADD 39023
# QRY 99999
# QRY 4711
# QRY 92325
# ADD 33578
# ADD 41072
# QRY 77084
# ADD 14093
# ADD 36766
# ADD 45608
# QRY 78096
# ADD 19324
# ADD 86902
# ADD 53560
# ADD 62886
# QRY 99999
# ADD 63707
# QRY 79704
# QRY 68633
# ADD 66512
# ADD 61928
# ADD 56141
# ADD 6924
# ADD 61302
# ADD 406
# ADD 96721
# QRY 99999
# ADD 29356
# ADD 82539
# ADD 63435
# ADD 45393
# ADD 89650
# QRY 99999
# QRY 36766
# ADD 23085
# ADD 73887
# ADD 26537
# QRY 71918
# ADD 82627
# ADD 32612
# ADD 35906
# QRY 99999
# QRY 63707
# QRY 19417
# ADD 38765
# QRY 68171
# QRY 75000
# QRY 53496
# ADD 6788
# QRY 47205
# ADD 9354
# QRY 68749
# ADD 23368
# ADD 86416
# ADD 21832
# ADD 34774
# ADD 68599
# ADD 90493
# ADD 52277
# QRY 99999
# QRY 77196
# QRY 99999
# QRY 52997
# ADD 90263
# ADD 88841
# QRY 99999
# QRY 99999
# ADD 61199
# QRY 22471
# ADD 63654
# QRY 99999
# ADD 17951
# ADD 66659
# QRY 48620
# ADD 82841
# ADD 23977
# QRY 15215
# ADD 63807
# ADD 68734
# QRY 77375
# ADD 52289
# ADD 35098
# QRY 99999
# ADD 11960
# QRY 99999
# ADD 70099
# QRY 40758
# ADD 89864
# QRY 26657
# ADD 62540
# QRY 52997
# ADD 73516
# QRY 73516
# QRY 52289
# ADD 71392
# ADD 24468
# QRY 99999
# QRY 48347
# QRY 19417
# QRY 31768
# QRY 8739
# QRY 93227
# ADD 58061
# ADD 41939
# QRY 65037
# QRY 61302
# QRY 18104
# ADD 18227
# QRY 99999
# QRY 53496
# ADD 57317
# ADD 95473
# ADD 86578
# QRY 99999
# ADD 93668
# ADD 29236
# ADD 31873
# ADD 87004
# ADD 94523
# ADD 45634
# ADD 19547
# QRY 38673
# ADD 3493
# QRY 43853
# QRY 99999
# QRY 77084
# ADD 54564
# ADD 18882
# QRY 99999
# QRY 19547
# ADD 65815
# QRY 86578
# ADD 96411
# ADD 65903
# ADD 88412
# QRY 47205
# QRY 45393
# ADD 289
# ADD 34963
# ADD 93616
# QRY 14787
# ADD 4126
# ADD 62198
# QRY 62842
# ADD 73767
# ADD 81408
# ADD 30263
# ADD 30663
# QRY 289
# QRY 90946
# QRY 99999
# ADD 98894
# QRY 68104
# ADD 35470
# QRY 103
# ADD 59767
# ADD 31001
# ADD 13178
# ADD 26517
# ADD 71619
# QRY 42965
# ADD 38698
# ADD 47100
# ADD 72901
# QRY 97506
# ADD 81982
# ADD 95763
# ADD 85338
# ADD 8966
# ADD 65106
# ADD 73478
# QRY 99999
# QRY 99999
# ADD 42987
# QRY 43850
# ADD 70944
# QRY 9663
# ADD 16885
# ADD 75560
# ADD 79243
# QRY 99999
# ADD 32871
# QRY 99999
# QRY 99999
# ADD 1394
# QRY 98894
# QRY 99999
# QRY 99999
# ADD 90130
# ADD 78346
# QRY 30364
# QRY 64013
# QRY 64023
# ADD 28714
# ADD 83690
# ADD 96723
# QRY 53496
# QRY 99999
# ADD 17360
# QRY 81892
# QRY 79243
# QRY 99999
# ADD 49390
# QRY 75837
# ADD 72795
# ADD 80535
# QRY 99999
# QRY 73478
# QRY 82539
# QRY 53285
# ADD 64087
# ADD 94000
# ADD 76522
# QRY 99999
# QRY 43439
# ADD 48525
# ADD 45001
# QRY 72795
# ADD 3175
# ADD 91946
# QRY 97293
# ADD 67567
# QRY 99999
# ADD 85468
# ADD 44701
# ADD 38402
# ADD 2322
# QRY 23368
# QRY 48347
# QRY 99999
# QRY 258
# ADD 5939
# ADD 45694
# QRY 63003
# QRY 11926
# QRY 74919
# QRY 68104
# QRY 99999
# QRY 56141
# ADD 84778
# QRY 96017
# QRY 99999
# ADD 34326
# ADD 9397
# ADD 80857
# ADD 3392
# ADD 45699
# ADD 77177
# QRY 94523
# QRY 3175
# ADD 30286
# QRY 55515
# ADD 50636
# ADD 44736
# QRY 99999
# ADD 27796
# QRY 43853
# QRY 99999
# ADD 69614
# QRY 35311
# QRY 99999
# QRY 9663
# ADD 45900
# ADD 57381
# QRY 7477
# QRY 99999
# QRY 20106
# QRY 45001
# ADD 43109
# ADD 4717
# ADD 48285
# ADD 15273
# QRY 99999
# QRY 63435
# QRY 61616
# QRY 55515
# ADD 92320
# QRY 14093
# ADD 25208
# ADD 16933
# ADD 44562
# ADD 28994
# ADD 58669
# ADD 11679
# QRY 90946
# ADD 64797
# QRY 99999
# ADD 57191
# QRY 76522
# ADD 61353
# ADD 77547
# ADD 17332
# ADD 38911
# QRY 99999
# QRY 25931
# QRY 72795
# ADD 26815
# ADD 75773
# ADD 47725
# ADD 86072
# ADD 33978
# ADD 25450
# QRY 99999
# QRY 24470
# ADD 23084
# QRY 81408
# QRY 55515
# ADD 86539
# QRY 85918
# ADD 60802
# ADD 32561
# ADD 16243
# QRY 14379
# QRY 526
# ADD 25441
# ADD 829
# ADD 28968
# ADD 56486
# QRY 35077
# ADD 67721
# QRY 54262
# ADD 33099
# ADD 97277
# QRY 99999
# QRY 35311
# ADD 51731
# QRY 79362
# QRY 65851
# QRY 30263
# ADD 57538
# QRY 73516
# QRY 17259
# QRY 99999
# QRY 99999
# QRY 73478
# QRY 99999
# QRY 34774
# ADD 88947
# QRY 99999
# ADD 14313
# ADD 44547
# ADD 96891
# QRY 99999
# ADD 88722
# QRY 99999
# QRY 32871
# QRY 31063
# ADD 79920
# ADD 95175
# QRY 71918
# QRY 20963
# ADD 20423
# ADD 17288
# QRY 99999
# ADD 60891
# ADD 79997
# QRY 99999
# ADD 84536
# QRY 1394
# QRY 54502
# ADD 81518
# QRY 28714
# ADD 14865
# ADD 454
# QRY 38402
# QRY 66659
# QRY 39023
# QRY 26657
# ADD 2577
# QRY 99999
# QRY 99999
# QRY 45393
# ADD 68817
# ADD 40344
# QRY 82841
# QRY 28786
# QRY 99999
# ADD 24806
# ADD 99126
# ADD 84465
# QRY 57191
# QRY 99999
# ADD 12004
# QRY 99999
# ADD 81628
# ADD 39035
# QRY 79997
# ADD 25405
# QRY 50887
# ADD 40794
# QRY 258
# QRY 99999
# ADD 5377
# ADD 79505
# ADD 5417
# QRY 99999
# ADD 80181
# QRY 99999
# QRY 99999
# QRY 39497
# QRY 9663
# QRY 99999
# ADD 97887
# QRY 33099
# ADD 84109
# ADD 57978
# QRY 99999
# ADD 49750
# QRY 30663
# QRY 69828
# ADD 17358
# ADD 17639
# ADD 64568
# ADD 21037
# QRY 99999
# QRY 78346
# ADD 73778
# QRY 29968
# ADD 82510
# ADD 15760
# QRY 99999
# QRY 38673
# ADD 48105
# ADD 10507
# ADD 38908
# QRY 68734
# QRY 99999
# QRY 30517
# ADD 87221
# QRY 86416
# QRY 67567
# ADD 87623
# ADD 72420
# ADD 51044
# ADD 51514
# ADD 17681
# QRY 3493
# ADD 56866
# QRY 63707
# ADD 7757
# ADD 16287
# ADD 22339
# QRY 40758
# QRY 43853
# ADD 74847
# ADD 73805
# QRY 68633
# QRY 99999
# ADD 1702
# ADD 98168
# ADD 8178
# QRY 62540
# QRY 46964
# QRY 52277
# ADD 71269
# ADD 75841
# QRY 99999
# QRY 49390
# QRY 99999
# ADD 27969
# QRY 99999
# QRY 85426
# ADD 72814
# ADD 31225
# ADD 50361
# ADD 62960
# QRY 99999
# ADD 88390
# ADD 38932
# QRY 20423
# QRY 99999
# QRY 99999
# ADD 43029
# ADD 42198
# ADD 63064
# QRY 63027
# QRY 29968
# ADD 3727
# ADD 73889
# ADD 18278
# ADD 61843
# QRY 99999
# QRY 96721
# ADD 67961
# QRY 74919
# ADD 21093
# ADD 46959
# QRY 29968
# ADD 49297
# ADD 59404
# ADD 20818
# ADD 14121
# QRY 49673
# QRY 94000
# ADD 54120
# QRY 30663
# QRY 98948
# ADD 46941
# ADD 20771
# QRY 71269
# ADD 72506
# ADD 43944
# ADD 48628
# ADD 97255
# QRY 99999
# ADD 11156
# QRY 99999
# QRY 58669
# QRY 99999
# ADD 8777
# QRY 44736
# ADD 18740
# ADD 14680
# ADD 24825
# QRY 87623
# ADD 2667
# ADD 64635
# QRY 99999
# ADD 39008
# QRY 68171
# QRY 99999
# QRY 99999
# ADD 68751
# QRY 63064
# QRY 64635
# QRY 56866
# QRY 99999
# QRY 99999
# ADD 39220
# ADD 78685
# ADD 84421
# QRY 57381
# ADD 4168
# QRY 3727
# QRY 92325
# ADD 29020
# QRY 43439
# ADD 40676
# QRY 21037
# ADD 52910
# QRY 71269
# ADD 57559
# ADD 88492
# QRY 38698
# QRY 99999
# ADD 67175
# ADD 48487
# ADD 46128
# ADD 43767
# ADD 32380
# ADD 4878
# QRY 99999
# QRY 48285
# QRY 45634
# ADD 42425
# QRY 41072
# QRY 90493
# QRY 99999
# QRY 99999
# ADD 96296
# QRY 42965
# QRY 77547
# ADD 71183
# ADD 20527
# ADD 93477
# QRY 62886
# QRY 99999
# QRY 33099
# ADD 86807
# ADD 38230
# QRY 99999
# QRY 85338
# QRY 67633
# QRY 99999
# QRY 99999
# ADD 77560
# ADD 30603
# ADD 93867
# ADD 73987
# ADD 77007
# QRY 99999
# QRY 45393
# QRY 148
# QRY 99999
# QRY 25405
# QRY 28786
# ADD 51195
# ADD 27658
# QRY 86539
# QRY 61214
# ADD 90047
# ADD 16873
# QRY 1394
# ADD 40000
# QRY 99999
# QRY 72901
# QRY 6788
# QRY 49390
# ADD 54567
# ADD 57084
# ADD 7287
# QRY 99999
# QRY 85918
# QRY 99999
# ADD 99680
# ADD 74074
# ADD 94558
# ADD 26294
# QRY 99999
# ADD 66304
# ADD 24681
# ADD 5704
# ADD 13836
# QRY 75363
# ADD 64479
# QRY 99999
# QRY 77084
# ADD 2429
# QRY 23084
# ADD 58772
# QRY 99999
# QRY 93616
# ADD 63748
# ADD 32081
# QRY 17332
# ADD 33563
# QRY 21832
# QRY 99999
# ADD 24176
# QRY 99999
# QRY 30603
# QRY 99999
# QRY 99999
# ADD 19482
# ADD 27015
# QRY 66512
# ADD 69479
# ADD 57424
# ADD 44234
# ADD 96584
# ADD 98373
# ADD 90261
# QRY 47205
# ADD 18293
# QRY 43767
# ADD 39091
# QRY 67087
# QRY 50887
# QRY 84778
# ADD 57199
# QRY 33578
# QRY 81982
# ADD 11201
# ADD 5105
# QRY 71183
# ADD 34847
# ADD 95717
# ADD 39769
# QRY 99999
# QRY 86578
# ADD 20479
# QRY 74919
# QRY 46964
# ADD 90501
# ADD 41777
# ADD 91847
# QRY 57742
# QRY 81892
# ADD 3781
# ADD 68348
# QRY 99999
# ADD 537
# QRY 99999
# END
# """

# entrada_ = entrada_.split('\n')
# print(entrada_)
# Out:
# ['ADD 74894', 'ADD 92325', 'ADD 47205', 'ADD 20184', 'ADD 75837', 'ADD 90523', 'ADD 91697', 'ADD 33302', 'ADD 79362', 'ADD 41288', 'ADD 49739', 'ADD 38145', 'ADD 74919', 'ADD 94022', 'ADD 2564', 'ADD 39908', 'ADD 79448', 'ADD 18241', 'ADD 79704', 'ADD 59722', 'ADD 66853', 'ADD 77084', 'ADD 64023', 'ADD 51796', 'ADD 43439', 'ADD 91429', 'ADD 18178', 'ADD 148', 'ADD 29968', 'ADD 76064', 'ADD 39497', 'ADD 41388', 'QRY 99999', 'ADD 49673', 'QRY 66853', 'ADD 62842', 'ADD 25931', 'ADD 85426', 'QRY 94022', 'ADD 14379', 'ADD 4711', 'ADD 96017', 'QRY 99999', 'ADD 97506', 'ADD 57742', 'QRY 99999', 'ADD 28786', 'ADD 65726', 'QRY 97506', 'QRY 91697', 'ADD 27604', 'QRY 92325', 'ADD 85918', 'ADD 94020', 'QRY 96017', 'ADD 94788', 'QRY 47205', 'ADD 31063', 'ADD 81892', 'QRY 79448', 'QRY 85918', 'QRY 27604', 'ADD 63027', 'QRY 99999', 'ADD 98728', 'QRY 31063', 'QRY 65726', 'ADD 81132', 'QRY 99999', 'QRY 74894', 'QRY 66853', 'QRY 99999', 'ADD 68104', 'QRY 99999', 'QRY 66853', 'QRY 74919', 'ADD 24470', 
# ...

# %%
# # while(True):
#     # entrada = input('ADD, REM, QRY:')
# ordem = int(len(entrada_))
# aux = 0
# while(aux != ordem):
#     entrada = entrada_[aux]
#     #####################################################################
#     if entrada =='END':
#         break
#     else:
#         entrada = entrada.split(' ')
#         entrada[-1] = int(entrada[-1])


#     # Para pegar o andar correto.
#     andar = entrada[-1] % M

#     # TODO: Checar quantos andares eu tenho.
#     # Se tiver 1 andar e ele estiver completo eu irei precisar criar um novo prédio e o len dele vai ser predio = 2*len(predio) + 1
#     flag_lotado = False

#     for andar in range(len(predio)):
#         if predio[f'Andar {andar}'].length() == L:
#             # A bandeira só muda se todos os andares estiverem lotados
#             flag_lotado = True

#     # Finalizando o andar correto.


#     if flag_lotado == False:
#         if entrada[0] == 'ADD':
#             # Acessando o andar no prédio do cimitério
#             predio[f'Andar {andar}'].push(entrada[-1])

#             # Colocar o método locate que vai retornar apenas a cova.
#             flag, conteudo = predio[f'Andar {andar}'].locate_num(entrada[-1])

#             if flag == True:
#                 print(f'{andar}.'+ conteudo)
#             else:
#                 print('?.?')

#         elif entrada[0] == 'REM':
#             # Acessando o andar no prédio do cimitério
#             predio[f'Andar {andar}'].remove_body(entrada[-1])

#             # Colocar o método locate que vai retornar apenas a cova.
#             flag, conteudo = predio[f'Andar {andar}'].remove_body(entrada[-1])

#             if flag == True:
#                 print(f'{andar}.'+ conteudo)
#             else:
#                 print('?.?')

#         elif entrada[0] == 'QRY': # Preciso de um método que localize a jazida que está o corpo _______.
#             # Acessando o andar no prédio do cimitério
#             predio[f'Andar {andar}'].locate_num(entrada[-1])

#             # Colocar o método locate que vai retornar apenas a cova.
#             flag, conteudo = predio[f'Andar {andar}'].locate_num(entrada[-1])

#             if flag == True:
#                 print(f'{andar}.'+ conteudo)
#             else:
#                 print('?.?')

#     else:
#         # Vamos fazer a redistribuição, criar um novo predio dict e colocar o len dele para 2M + 1.
#         aux_predio = predio
#         predio = {}

#         for i in range((2 * (len(aux_predio))) + 1):
#             # Dicionário que receberá uma double linked list.
#             # L = self.size = size ; size é um parâmetro que usaremos para comparar e descobrir se todas as Jazidas estão ocupadas.
#             predio[f'Andar {i}'] = DoubleLinkedList(L)

#         # Nessa parte aqui eu já terei o prédio novo criado, agora preciso fazer o realocamento das covas.
#         # Rehash

#         # Vou ter que fazer isso para cada andar
#         # for andar in range(len(aux_predio)):
#         #     aux_predio[f'Andar {andar}'].redistribuir(predio) # Vai enviar prédio para o aux_predio, para conseguir fazer a distribuição.



#         andar = len(aux_predio)
#         # print(aux_predio)

#         for andar in range(len(aux_predio)):
#             for cova in range(L): # (aux_predio[f'Andar {andar}'].lenght()):
#                 if aux_predio[f'Andar {andar}'].first.body_removed == True:
#                    pass
#                 else:
#                     print()
#                     predio[f'Andar {andar}'].push(aux_predio[f'Andar {andar}'].first.get_label())

#                 aux_predio[f'Andar {andar}'].first.getNext()

#         # Lembrar da variável que eu mudei para TRUE para não alocar o corpo que foi removido.

#     aux = aux + 1

# %%
# while(True):
    # entrada = input('ADD, REM, QRY:')
flag_oq_ta_acontecendo = False
ordem = int(len(entrada_))
aux = 0
while(aux != ordem):
    entrada = entrada_[aux]
    #####################################################################
    if entrada =='END':
        break

    else:
        entrada = entrada.split(' ')
        entrada[-1] = int(entrada[-1])

    flag_lotado = False

    for andar in range(len(predio)):
        if predio[f'Andar {andar}'].length() == L:
            # A bandeira só muda se todos os andares estiverem lotados
            flag_lotado = True

    # Finalizando o andar correto.

    if flag_lotado == False:
        if entrada[0] == 'ADD':
            andar = entrada[-1] % M

            if flag_oq_ta_acontecendo == True:
                print(f"ADD {entrada[-1]}")
                print(f"Será no andar {andar}, porque {entrada[-1]} mod {M} = {entrada[-1] % M}")
                predio['Andar 0'].show()
                predio['Andar 1'].show()
                predio['Andar 2'].show()

            
            # Acessando o andar no prédio do cimitério
            predio[f'Andar {andar}'].push(entrada[-1])

            # Colocar o método locate que vai retornar apenas a cova.
            flag, conteudo = predio[f'Andar {andar}'].locate_num(entrada[-1])
            
            if flag == True:
                print(f'{andar}.'+ conteudo)
            else:
                print('?.?')

            # print('\n')

        elif entrada[0] == 'REM':
            andar = entrada[-1] % M
            # Acessando o andar no prédio do cimitério
            predio[f'Andar {andar}'].remove_body(entrada[-1])

            # Colocar o método locate que vai retornar apenas a cova.
            flag, conteudo = predio[f'Andar {andar}'].remove_body(entrada[-1])

            if flag == True:
                print(f'{andar}.'+ conteudo)
            else:
                print('?.?')

            # print('\n')

        elif entrada[0] == 'QRY': # Preciso de um método que localize a jazida que está o corpo _______.
            andar = entrada[-1] % M
            # Acessando o andar no prédio do cimitério
            predio[f'Andar {andar}'].locate_num(entrada[-1])

            # Colocar o método locate que vai retornar apenas a cova.
            flag, conteudo = predio[f'Andar {andar}'].locate_num(entrada[-1])

            if flag == True:
                print(f'{andar}.'+ conteudo)
            else:
                print('?.?')

            # print('\n')

    else:
        aux_predio = predio
        predio = {}

        for i in range((2 * (len(aux_predio))) + 1):
            predio[f'Andar {i}'] = DoubleLinkedList(L)

        andar = len(aux_predio)

        for andar in range(len(aux_predio)):
            # Pegando o valor do primeiro nodo.
            next_node = aux_predio[f'Andar {andar}'].first
            for cova in range(L): 
                if next_node is None:
                    break  # Chegamos ao fim da lista

                if next_node.body_removed == True:
                    pass
                else:
                    aux_ = next_node.getLabel() % len(predio)
                    predio[f'Andar {aux_}'].push(next_node.getLabel())

                next_node = next_node.getNext()  # Atualizamos para o próximo nó

        # predio['Andar 0'].show()
        # predio['Andar 1'].show()
        # predio['Andar 2'].show()

        flag_oq_ta_acontecendo = True

        M = len(predio)
        aux = aux -1

    aux = aux + 1
# Out:
# 0.0
# 0.1
# 0.0
# 0.0
# 0.3
# 0.4
# 0.5
# 0.1
# 0.5
# 0.2
# 0.4
# ADD 38145
# Será no andar 0, porque 38145 mod 3 = 0
# Ordem crescente:
# 20184 -> 47205 -> 75837 -> 79362 -> 92325
#
#
# Ordem crescente:
# 90523
#
#
# Ordem crescente:
# 33302 -> 41288 -> 49739 -> 74894 -> 91697
#
#
# 0.1
# ADD 74919
# Será no andar 0, porque 74919 mod 3 = 0
# Ordem crescente:
# 20184 -> 38145 -> 47205 -> 75837 -> 79362 -> 92325
#
#
# Ordem crescente:
# 90523
#
#
# Ordem crescente:
# 33302 -> 41288 -> 49739 -> 74894 -> 91697
#
#
# 0.3
# ADD 94022
# Será no andar 2, porque 94022 mod 3 = 2
# Ordem crescente:
# 20184 -> 38145 -> 47205 -> 74919 -> 75837 -> 79362 -> 92325
#
#
# Ordem crescente:
# 90523
#
#
# Ordem crescente:
# 33302 -> 41288 -> 49739 -> 74894 -> 91697
#
#
# 2.5
# ADD 2564
# Será no andar 2, porque 2564 mod 3 = 2
# Ordem crescente:
# 20184 -> 38145 -> 47205 -> 74919 -> 75837 -> 79362 -> 92325
#
#
# Ordem crescente:
# 90523
#
#
# Ordem crescente:
# ...

# %%
for i in range(len(predio)):
    predio[f'Andar {andar}'].show()
# Out:
# Ordem crescente:
# 6924 -> 20184 -> 46959 -> 48489
#
#
# Ordem crescente:
# 6924 -> 20184 -> 46959 -> 48489
#
#
# Ordem crescente:
# 6924 -> 20184 -> 46959 -> 48489
#
#
# Ordem crescente:
# 6924 -> 20184 -> 46959 -> 48489
#
#
# Ordem crescente:
# 6924 -> 20184 -> 46959 -> 48489
#
#
# Ordem crescente:
# 6924 -> 20184 -> 46959 -> 48489
#
#
# Ordem crescente:
# 6924 -> 20184 -> 46959 -> 48489
#
#
# Ordem crescente:
# 6924 -> 20184 -> 46959 -> 48489
#
#
# Ordem crescente:
# 6924 -> 20184 -> 46959 -> 48489
#
#
# Ordem crescente:
# 6924 -> 20184 -> 46959 -> 48489
#
#
# Ordem crescente:
# 6924 -> 20184 -> 46959 -> 48489
#
#
# Ordem crescente:
# 6924 -> 20184 -> 46959 -> 48489
#
#
# Ordem crescente:
# 6924 -> 20184 -> 46959 -> 48489
#
#
# Ordem crescente:
# 6924 -> 20184 -> 46959 -> 48489
#
#
# Ordem crescente:
# 6924 -> 20184 -> 46959 -> 48489
#
#
# Ordem crescente:
# 6924 -> 20184 -> 46959 -> 48489
#
#
# Ordem crescente:
# 6924 -> 20184 -> 46959 -> 48489
#
#
# Ordem crescente:
# ...

# %%
print(predio)
# Out:
# {'Andar 0': <__main__.DoubleLinkedList object at 0x000002BCECD4EC50>, 'Andar 1': <__main__.DoubleLinkedList object at 0x000002BCECCD35E0>, 'Andar 2': <__main__.DoubleLinkedList object at 0x000002BCECCD3640>, 'Andar 3': <__main__.DoubleLinkedList object at 0x000002BCECCD36A0>, 'Andar 4': <__main__.DoubleLinkedList object at 0x000002BCECCD3700>, 'Andar 5': <__main__.DoubleLinkedList object at 0x000002BCECCD3760>, 'Andar 6': <__main__.DoubleLinkedList object at 0x000002BCECCD37C0>, 'Andar 7': <__main__.DoubleLinkedList object at 0x000002BCECCD3820>, 'Andar 8': <__main__.DoubleLinkedList object at 0x000002BCECCD3880>, 'Andar 9': <__main__.DoubleLinkedList object at 0x000002BCECCD38E0>, 'Andar 10': <__main__.DoubleLinkedList object at 0x000002BCECCD3940>, 'Andar 11': <__main__.DoubleLinkedList object at 0x000002BCECCD39A0>, 'Andar 12': <__main__.DoubleLinkedList object at 0x000002BCECCD1FC0>, 'Andar 13': <__main__.DoubleLinkedList object at 0x000002BCECCD3A00>, 'Andar 14': <__main__.Doubl
# ...
